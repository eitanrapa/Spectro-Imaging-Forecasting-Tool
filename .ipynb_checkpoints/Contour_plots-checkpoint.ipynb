# %%
import MCMC as MCSZ
import numpy as np
import corner
import matplotlib.pyplot as plt
import pandas as pd
import time
from astropy.io import fits
from astropy.cosmology import FlatLambdaCDM
from astropy import units as u
import sys
import csv

# %%
#Specify fiducial values (Should be same as from sim_script)

#Galaxy cluster parameters
y = 15e-6
electron_temperature = 5.0 #KeV
tau = MCSZ.y_to_tau(y,electron_temperature)
peculiar_vel = 1100 #km/s
betac = peculiar_vel/(3e5)

#SIDES model values
amp_sides = 1
b_sides = 1

labels = ('tau','temperature','betac','amp_sides','b_sides')
theta = (y, electron_temperature, betac, amp_sides, b_sides)

# %%
# Read simulation output, change directory 
df = pd.read_csv('/data/bolocam/bolocam/erapaport/mcmc_test_run203',header=None) 
data = df.to_numpy()

# %%
#Plot contour plot
fig = corner.corner(
    data, labels=labels, truths=theta, smooth = 0
);
