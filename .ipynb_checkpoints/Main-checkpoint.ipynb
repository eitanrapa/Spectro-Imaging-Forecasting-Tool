# %%
import BIAS_classes as BIAS
import numpy as np

# %%
#Band definitions
#3 Channel case
pix1 = 50
pix2 = 136
pix3 = 282
pix4 = 460

# I tune these by eye so that we get 3 channels per sub-band
res1 = 17
res2 = 39
res3 = 26
res4 = 27

NEP1 = np.sqrt(8.87**2 + 3.1**2)
NEP2 = np.sqrt(10.4**2 + 2.53**2)
NEP3 = np.sqrt(6.9**2 + 1.37**2)
NEP4 = np.sqrt(7.12**2 + 1.00**2) # all in aW/rtHz units

Bands_list1 = [{'name':'Band 1','nu_meanGHz':145,'FBW':0.3,'nu_resGHz':res1,'NEP_aWrtHz':NEP1,'N_pixels':pix1},\
      {'name':'Band 2','nu_meanGHz':250,'FBW':0.4,'nu_resGHz':res2,'NEP_aWrtHz':NEP2,'N_pixels':pix2},\
      {'name':'Band 3','nu_meanGHz':365,'FBW':0.18,'nu_resGHz':res3,'NEP_aWrtHz':NEP3,'N_pixels':pix3},\
      {'name':'Band 4','nu_meanGHz':460,'FBW':0.15,'nu_resGHz':res4,'NEP_aWrtHz':NEP4,'N_pixels':pix4}]

#Time = 86400 #1 day
#Time = 604800 #1 week
#Time = 3600.0  #1 hour
#Time = 3.154E7 # 1 year
Time = 288000 #80 hours
#Time = 72000 #20 hours

# %%
#Galaxy cluster parameters
y = 5.4e-5
electron_temperature = 5.0 #KeV
peculiar_vel = 0.000001 #km/s
betac = peculiar_vel/(3e5)

# %%
test = BIAS.Spectral_Simulation_SOFTS(y, electron_temperature, peculiar_vel, Bands_list1, Time)

# %%
#Run Simulation

# %%
biasclass.run_sim(run_names[i], "HYBRID", processors_pool = 12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-69de494acda5> in <module>
# ----> 1 biasclass.run_sim(run_names[i], "HYBRID", processors_pool = 12)
#
# NameError: name 'biasclass' is not defined

# %%
#Create Differential Intensity Projections

#Specify which SIDES pixel to look at 
SIDES_longitude = 120
SIDES_latitude = 120

test.Differential_Intensity_Projection("HYBRID",SIDES_longitude, SIDES_latitude)

# %%
#Create Contour Plots

fig, new_data = test.Contour_Plot_Projection("324")

# %%
print(np.std(new_data[:,2]*3e5))
print(np.std(new_data[:,0]))
# Out:
# 47.95827292124381
# 6.508155986810637e-07

# %%
new_new_data = []
for i in range(len(new_data[:,2])):
    if new_data[i,2] > -0.005 and new_data[i,2] < 0.005:
        new_new_data.append(new_data[i,2])
new_new_data = np.asarray(new_new_data)
print(np.std(new_new_data*3e5))
# Out:
# 47.95827292124381

# %%
#Galaxy cluster parameters
y = 6e-6
electron_temperature = 5.0 #KeV
peculiar_vel = 0.000001 #km/s
betac = peculiar_vel/(3e5)
#Time = 86400 #1 day
#Time = 604800 #1 week
#Time = 3600.0  #1 hour
#Time = 3.154E7 # 1 year
Time = 288000 #80 hours
#Time = 72000 #20 hours
test = BIAS.Spectral_Simulation_SOFTS(y, electron_temperature, peculiar_vel, Bands_list1, Time)
fig, new_data1, new_data2 = test.Contour_Plot_Double_Projection("016","303")
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-55ef5aa1b0ed> in <module>
#      11 #Time = 72000 #20 hours
#      12 test = BIAS.Spectral_Simulation_SOFTS(y, electron_temperature, peculiar_vel, Bands_list1, Time)
# ---> 13 fig, new_data1, new_data2 = test.Contour_Plot_Double_Projection("016","303")
#
# ~/erapaport/BIAS/BIAS_classes.py in Contour_Plot_Double_Projection(self, run_number1, run_number2)
#     387         #Plot contour plot
#     388         GTC = pygtc.plotGTC(chains=[new_data1,new_data2], chainLabels=chainLabels, truths=theta, paramNames = labels,figureSize=10)
# --> 389         GTC.set_yscale('log')
#     390
#     391         return GTC, new_data1, new_data2
#
# AttributeError: 'Figure' object has no attribute 'set_yscale'

# %%
print(np.std(new_data1[:,2]*3e5))
print(np.std(new_data1[:,0]))
print(np.std(new_data2[:,2]*3e5))
print(np.std(new_data2[:,0]))
# Out:
# 362.6519064501725
# 4.764544275960443e-07
# 344.76364698934265
# 4.403506947034828e-07

# %%
fig, new_data1, new_data2 = test.Contour_Plot_Double_Projection("016","203")

# %%
print(np.std(new_data1[:,2]*3e5))
print(np.std(new_data1[:,0]))
print(np.std(new_data2[:,2]*3e5))
print(np.std(new_data2[:,0]))
# Out:
# 362.6519064501725
# 4.764544275960443e-07
# 382.2075691656128
# 5.246537745096209e-07
